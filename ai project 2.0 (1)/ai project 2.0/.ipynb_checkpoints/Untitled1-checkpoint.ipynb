# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('Diamonds Prices2022.csv')

# %%
import seaborn as sns
cols = ['x', 'y', 'z', 'table','carat','depth','price']
corr_matrix = df[cols].corr()
sns.heatmap(corr_matrix.iloc[:7,:7], annot=True, cmap='coolwarm')
plt.show()




ax.set_xlabel('data ')
ax.set_ylabel('price')
ax.legend()

plt.show()

fig, ax = plt.subplots()

ax.scatter(df['carat'], df['price'], label='carat')
ax.scatter(df['x'], df['price'], label='x ')
ax.scatter(df['y'], df['price'], label='y )')
ax.scatter(df['z'], df['price'], label='z ')

ax.set_xlabel('Dimensions (mm)')
ax.set_ylabel('Price ($)')
ax.legend()

plt.show()

# %%
from sklearn.model_selection import train_test_split

df=df.dropna()
x = df[[ 'carat','x','y','z']]
y = df['price']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)

# %%
import tensorflow as tf 
def build_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(32, activation='relu', input_shape=[len(x_train.keys())]),
        tf.keras.layers.Dense(64, activation='relu'),
         
        tf.keras.layers.Dense(1)
    ])
    optimizer = tf.keras.optimizers.Adam(0.001)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae', 'mse'])
    history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_val, y_val),verbose=0)

    return model,history
model,history = build_model()

# %%
loss, mae, mse = model.evaluate(x_test, y_test, verbose=0)
y_pred = model.predict(x_test)
print('Loss:', loss)
print('MAE:', mae)
print('RMSE:', np.sqrt(mse))
print('R^2 score:', r2_score(y_test, y_pred))


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model convergence')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()
# Out:
# 338/338 [==============================] - 0s 440us/step
# Loss: 2066092.375
# MAE: 819.9771728515625
# RMSE: 1437.3908219409223
# R^2 score: 0.8676696577100147

# %%
fig, ax = plt.subplots()

ax.scatter(x_test['carat'],y_pred, label='carat')
ax.scatter(x_test['x'],y_pred, label='x size (mm)')
ax.scatter(x_test['y'], y_pred, label='y size (mm)')
ax.scatter(x_test['z'],y_pred, label='z size (mm)')



ax.set_xlabel('Dimensions ')
ax.set_ylabel('price')
ax.legend()

plt.show()

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()
